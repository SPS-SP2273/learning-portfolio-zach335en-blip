# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Loops (Good) Exercises</span></div>

# %%
import numpy as np

# %% [markdown]
# # Exercise 1 (Make me an odd list)

# %%
squares_list = []
for number in range (10):
    if number % 2 == 0:
        continue
    squares_list.append(number**2)
print(squares_list)
# Out:
# [1, 9, 25, 49, 81]

# %% [markdown]
# # Exercise 2 (Make me another odd list)

# %%
[number**2 for number in range (10) if number % 2 > 0]
# Out:
# [1, 9, 25, 49, 81]

# %% [markdown]
# # Exercise 3 (Time me!)

# %%
# %%timeit -n 1000 -r 10

squares_list = []
for number in range (10):
    if number % 2 == 0:
        continue
    squares_list.append(number**2)
print(squares_list)
# Out:
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# [1, 9, 25, 49, 81]
# ...

# %%
# %%timeit -n 1000 -r 10
[number**2 for number in range (10) if number % 2 > 0]
# Out:
# 1.18 μs ± 338 ns per loop (mean ± std. dev. of 10 runs, 1,000 loops each)

# %% [markdown]
# `%%timeit` command set to 1000 loops for 10 runs to increase processing speed.
# Second solution is faster by 0.2s

# %% [markdown]
# # Exercise 4 (A problem of decay)

# %%
quantity = 100
time = 0
while quantity > 50:
    quantity = quantity*(0.95**time)
    time += 1
    final_time = np.max(time)
print(f'The sample will take {final_time} years to reduce to half its original product')
# Out:
# The sample will take 6 years to reduce to half its original product

# %% [markdown]
# # Exercise 5 (Changes in CO<sub>2</sub>)

# %%
co2_data = [
    (2000, 369.55), (2001, 371.14), (2002, 373.28), 
    (2003, 375.80), (2004, 377.52), (2005, 379.80), 
    (2006, 381.90), (2007, 383.79), (2008, 385.60), 
    (2009, 387.43), (2010, 389.90), (2011, 391.65), 
    (2012, 393.85), (2013, 396.52), (2014, 398.65),
    (2015, 400.83), (2016, 404.24), (2017, 406.55), 
    (2018, 408.52), (2019, 411.44), (2020, 414.24)
]

# %%
for data in range (1, len(co2_data)):
    previous_year, previous_ppm = co2_data[data - 1]
    year, ppm = co2_data[data]
    ppm_data = ppm - previous_ppm
    if ppm_data > 3:
        print(f"{year}, {ppm_data :.2f}")
# Out:
# 2016, 3.41
